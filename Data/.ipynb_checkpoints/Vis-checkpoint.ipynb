# %%
#coding:utf-8
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mlt
from matplotlib.font_manager import _rebuild
_rebuild()

# %%
File_Path = 'NZ_Admin_JOBS_finished.xlsx'
Reading_Engine = 'openpyxl'
pd.set_option('max_columns',100) 
pd.set_option('max_rows',500)
sns.set_style('whitegrid')
# plt.rcParams['font.sans-serif']=['SemHei']  # 设置字体为 黑体
plt.rcParams['axes.unicode_minus']=False # 显示符号
plt.rcParams.update({
    'font.family':'sans-serif',
    'font.sans-serif':['SemHei'],
    })
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel(File_Path, engine=Reading_Engine)
data.drop('Unnamed: 0',axis=1, inplace=True)
data.head(20)
# Out:
#                                             Job_Title  \
# 0                                       Administrator
# 1                                        Receptionist
# 2                        Prosecutions Support Officer
# 3                Early Childhood Centre Administrator
# 4                      Business Support Administrator
# 5                                     Support Officer
# 6                                     Support Officer
# 7                                office administrator
# 8                                Office Administrator
# 9                              Administration Officer
# 10                             Administration Officer
# 11                                         Data Entry
# 12            Office Admin Assistant (10hrs per week)
# 13                               Office Administrator
# 14                               Office Administrator
# 15                           Customer Service Officer
# ...

# %% [markdown]
# ## Location and Job counts

# %%
d1 = data.Location.value_counts()
d1
# Out:
# Auckland         891
# Wellington       854
# Waikato          404
# Canterbury       203
# Bay of Plenty     93
# Manawatu          92
# Northland         78
# Otago             40
# Hawkes Bay        19
# Taranaki          10
# Tasman             8
# Southland          7
# Gisborne           4
# Marlborough        4
# West Coast         1
# Name: Location, dtype: int64

# %%
x = d1.index
x
# Out:
# Index(['Auckland', 'Wellington', 'Waikato', 'Canterbury', 'Bay of Plenty',
#        'Manawatu', 'Northland', 'Otago', 'Hawkes Bay', 'Taranaki', 'Tasman',
#        'Southland', 'Gisborne', 'Marlborough', 'West Coast'],
#       dtype='object')

# %%
y = d1.values
y
# Out:
# array([891, 854, 404, 203,  93,  92,  78,  40,  19,  10,   8,   7,   4,
#          4,   1])

# %%
plt.figure(figsize=(10,6))
plt.bar(x,y,color='b')
plt.title('Total Jobs in Diferent Location', fontsize=20)
plt.xlabel('Location', fontsize=18)
plt.ylabel('Job Counts', fontsize=18)
plt.tick_params(labelsize=14)
plt.xticks(rotation=90)
for a,b in zip(x,y):
    plt.text(a, b+5, b, fontsize=10, ha='center', va='bottom')
plt.show()

# %%
data.Time_Posted.dtype
# Out:
# dtype('int64')

# %%
d2 = data.Time_Posted.value_counts()
d2 = d2.sort_index()[-1::-1]
d2
# Out:
# 274       1
# 213       2
# 9         2
# 8         4
# 7       133
# 6        70
# 5        55
# 4       116
# 3        60
# 2         3
# 0      2262
# Name: Time_Posted, dtype: int64

# %%
x = d2.index
y = d2.values

plt.figure(figsize=[15,6])
plt.plot(x, y, colour='r')

plt.title('Number of Jobs in times')
