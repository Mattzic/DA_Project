# %%
import numpy as np
import pandas as pd
import re
from numpy.random import default_rng

pd.set_option('max_columns',100) 
pd.set_option('max_rows',500)  
File_Path = 'NZ_Admin_JOBS.xlsx'
Reading_Engine = 'openpyxl'
Columns = ['Job_Title', 'Link', 'Orgnisation', 'Location', 'Time_Posted', 'Classification']
File_Save = 'NZ_Admin_JOBS_finished.xlsx'

def Read_Data():
    data = pd.read_excel(File_Path, engine=Reading_Engine)
    # data.drop('Unnamed: 0',axis=1, inplace=True)
    return data

# Assign names to columns
def Name_Columns(data):
    data.columns = Columns
    return data

# Fill Nan's in 'Orgnisation' with 'Private Advertiser'
def Set_Orgnisation(data):
    data.Orgnisation.fillna('Private Advertiser', inplace=True)
    return data

# Extract salary info from 'Classification' and make a new column 'Salary'
def Extract_Salary(data):
    def apply_saraly(a):
        if 'classification:' in a:
            return None
        else:
            return a
    data['Salary'] = data.Classification.apply(apply_saraly)
    return data

# Clean salary info in 'Classificaiton'
def Clean_SaInfo(data):
    def clean_salary(a):
        if 'classification:' in a:
            return a
        else:
            return 'None'
    data.Classification = data.Classification.apply(clean_salary)
    return data

def deduplication(x):
    x = x.strip()
    if x == 'None':
        return 'None'
    return re.match(r'(.*)\1', x).group(1)

def Clean_Classification(data):
    data = Extract_Salary(data)
    data = Clean_SaInfo(data)
    
    # Split 'Classification' into 'Subclassification' and 'Classification' 
    data[['Classification', 'Subclassification']] = data.Classification.str.split('subClassification:', expand=True)
    
    # Get rid of 'classification:'
    data.Classification = data.Classification.str.replace('classification:','')
    
    # Set 'Subclassification' dtype to str and deduplicate 'Subclassification'
    data.Subclassification = data.Subclassification.astype('str')
    data.Subclassification = data.Subclassification.apply(deduplication)
    
    # Set 'Classification' dtype to str and deduplicate 'Classification'
    data.Classification = data.Classification.astype('str')
    data.Classification = data.Classification.apply(deduplication)
    return data

# Clean 'Location'
def Clean_Location(data):
    
    # Split 'Location' into 'Location' and 'Area' 
    data[['Location', 'Area']] = data.Location.str.split('area:', expand=True)
    
    # Get rid of 'location:' in 'Location' and deduplicate 'Location'
    data.Location = data.Location.str.replace('location:','')
    data.Location = data.Location.apply(deduplication)
    return data

# Clean 'Area'
def Clean_Area(data):
    
    # Get rid of salary info from 'Area'
    data['Area'] = data.Area.str.replace(r'(.*[a-z]),.+', r'\1', regex=True)
    
    # Set 'Area' dtype to str and deduplicate 'Area'
    data.Area = data.Area.astype('str')
    data.Area = data.Area.apply(deduplication)
    return data

# Clean 'Time_Posted'
def Clean_Time_Posted(data):
    
    # If not in some form similar to '7d ago', set it to 0
    # otherwise extract '7d' 
    def apply_TP(x):
        if re.match(r'^(\d[a-z]\s)',x):
            return re.match(r'^(\d[a-z])\s',x).group(1)
        else:
            return 0   
    
    data['Time_Posted'] = data['Time_Posted'].astype('str')
    data['Time_Posted'] = data['Time_Posted'].apply(apply_TP) 

    # Time should be measured in days  
    def date_transfer(x):
        if x == '0' or 'h' in x:
            return 0
        y = int(x[:-1])
        if 'd' in x:
            return y
        if 'm' in x:
            return y // 2 * 31 + (y - y // 2) * 30
    
    data['Time_Posted'] = data['Time_Posted'].astype('str')
    data['Time_Posted'] = data['Time_Posted'].apply(date_transfer)
    return data

# Clean 'Salary'
def Clean_Salary(data):
    
    # Get rid of ','
    data.Salary = data.Salary.str.replace(',','')
    
    # Replace 'to' with '-' and split 'Salary' by the first '-' intp 'Lo_Salary' and 'Hi_salary'
    data.Salary = data.Salary.str.replace('to','-',regex=True)
    data[['Lo_Salary', 'Hi_Salary'] ] = data.Salary.str.split('-', n=1, expand=True)
    
    return data

# 1.Check if the str contains digits
# 2. If it does, check if it is a percentage
# 3. If it is, leave it there with no change, "8% holiday pay" -> "8% holiday pay"
# 3. If it is a salary, convert it to annual salary 
# 4. Fomular:  x * 8 * 20 * 10
# 5. Only keep numeric info, "NZD75000 per annum" -> "75000.0"; "NZD25" -> "40000.0"
def to_annual(x):
    matchObj = re.match('[^0-9]*(\d+\.*\d*)\s*[a-z]*',x)
    if matchObj:
        if (re.match('.*\d+\.*\d*\s*\%', x)) and ("$" not in x):
            pass
        else:
            x = float(matchObj.group(1))
            # Assume that under 60 is salary per hour
            if x < 60:
                x = x * 8 * 20 * 10
            # For x in between 60 and 250, assume it to be annual salary but without a 'k' for some reason   
            elif x < 250:
                x = x * 1000
            else:
                pass
    return x

# Find max and min in some column
def Find_Value(data, column):
    df1 = data[data[column].str.contains(r'\d$', regex=True, na=False)][column]
    df1 = df1[df1.values!='0.0']
    df1 = df1.astype('float')
    return df1.max(),df1.min()

# Clean 'Lo_Salary'
def Clean_LSalary(data):
    data['Lo_Salary'] = data['Lo_Salary'].astype('str')

    # Get rid of white space within a number
    data['Lo_Salary'] = data['Lo_Salary'].str.replace(r'(\d+)\s(\d+)', r'\1\2', regex=True)

    # Replace 'k' with '000'
    data['Lo_Salary'] = data['Lo_Salary'].str.replace(r'k', r'000',case=False)

    data['Lo_Salary'] = data['Lo_Salary'].apply(to_annual)
    
    # Fill all nan's with some artificially made data
    data['Lo_Salary'] = data['Lo_Salary'].astype('str')
    max_LS, min_LS = Find_Value(data,'Lo_Salary')

    # Generate random values in between max and min
    def set_value(x):
        rng = default_rng()
        if x == 'None':
            x = rng.integers(min_LS, max_LS, endpoint=True)
        return x
    
    data['Lo_Salary'] = data['Lo_Salary'].apply(set_value)

    # There is one special case
    # 'Salary' is "Up to $23 p.h. + + 8% Holiday Pay"
    # The info in 'Lo_Salary' would be 'Up '
    # We need set some value to it and make it less than what in 'Hi_Salary' 
    rng = default_rng()
    for index, value in enumerate(data['Lo_Salary'].values):
        if data['Lo_Salary'][index] == 'Up ':
            num = int(rng.integers(20, int(re.match('[^0-9]*(\d+)\.*\d*\s*',data['Hi_Salary'][index]).group(1))))
            data.loc[index, 'Lo_Salary'] = num * 8 * 20 * 10
    return data

# %%
# Clean 'Hi_Salary'
def Clean_HSalary(data):
    data['Hi_Salary'] = data['Hi_Salary'].astype('str')
    data['Hi_Salary'] = data['Hi_Salary'].str.replace(r'(\d+)\s(\d+)', r'\1\2', regex=True)
    data['Hi_Salary'] = data['Hi_Salary'].str.replace('k', '000', case=False)
    data['Hi_Salary'] = data['Hi_Salary'].apply(to_annual)
    data['Hi_Salary'] = data['Hi_Salary'].astype('str')
    max_LS, min_LS = Find_Value(data,'Hi_Salary')
    
    data['Hi_Salary'] = data['Hi_Salary'].astype('str')
    data['Lo_Salary'] = data['Lo_Salary'].astype('str')
    rng = default_rng()

    # less than max, greater than max(Lo_Salary, min)
    for i, v in enumerate(data['Hi_Salary'].values):
        v = v.strip()
        if v == 'None':
            if re.match('^\d+\.*\d*$', data['Lo_Salary'][i]):
                Lo = float(data['Lo_Salary'][i])
                min_LS = max(min_LS, Lo)
                num = rng.integers(max(min_LS,float(data['Lo_Salary'][i])), max_LS)        
            # if it is some str in 'Lo_Salary' like 'Good salary' or 'bonus plus medical insurance', do noting
            elif re.match('.*[a-z]+\s*$', data['Lo_Salary'][i]):
                continue
            else:
                num = rng.integers(min_LS, max_LS)
            data.loc[i, 'Hi_Salary'] = num
    
    return data

# %%
def Clean(data):
    data = Name_Columns(data)
    data = Set_Orgnisation(data)
    data = Clean_Classification(data)
    data = Clean_Location(data)
    data = Clean_Area(data)
    data = Clean_Time_Posted(data)
    data = Clean_Salary(data)
    data = Clean_LSalary(data)
    data = Clean_HSalary(data)
#     return data

data = Read_Data()
Clean(data)

# if __name__ == '__main__':
#     data = Read_Data()
#     data = Clean(data)
#     data.to_excel(File_Save)

# %%
data.head(500)
# Out:
#                                              Job_Title  \
# 0                                        Administrator
# 1                                         Receptionist
# 2                         Prosecutions Support Officer
# 3                 Early Childhood Centre Administrator
# 4                       Business Support Administrator
# 5                                      Support Officer
# 6                                      Support Officer
# 7                                 office administrator
# 8                                 Office Administrator
# 9                               Administration Officer
# 10                              Administration Officer
# 11                                          Data Entry
# 12             Office Admin Assistant (10hrs per week)
# 13                                Office Administrator
# 14                                Office Administrator
# 15                            Customer Service Officer
# 16            Administration Assistant - Mt Wellington
# 17   Part-time Health & Disability Administrative A...
# 18           Office Coordinator, Whangarei Youth Space
# 19                                       Administrator
# 20                  Administration Officer - Part Time
# 21                     Part-time Admin/Accounts Person
# 22                      Business Support Administrator
# 23                             Reception/Administrator
# 24                                 Office Co-Ordinator
# 25                                Office Administrator
# 26                   Administration & Customer Service
# 27                                       Administrator
# 28                        RECEPTIONIST / ADMINISTRATOR
# 29                      Administrator - Street to Home
# 30                              Administrative Support
# 31                                Medical Receptionist
# 32                Receptionist / Office Administration
# 33                    People and Culture Administrator
# 34                              Senior Support Officer
# 35                                       Administrator
# 36                                office administrator
# 37    Provider Registration Administrator - Lower Hutt
# 38                        Receptionist / Admin Support
# 39   Colliers Rural - Office Administrator (Part time)
# 40                             Part Time Administrator
# 41                            Operations Administrator
# 42               Receptionist / Accounts Administrator
# 43                               Office Administrators
# 44                       Accounts and Office Assistant
# 45                   Administrator/Secretarial Support
# 46             Supporter Care & Database Administrator
# 47                    Personal Assistant/Administrator
# 48         Administrative and Organisational Superstar
# 49                                    Office Assistant
# 50   Administrator (including School Bus Co-ordinator)
# 51                                Office Administrator
# 52                           Administration Specialist
# 53                              Administration Officer
# 54                            Business Support Officer
# 55        Customer Services and Administration Officer
# 56                  Clinical Administrator (Job Share)
# 57                       Office / Client Administrator
# 58                     Office / Administration Manager
# 59                FULL TIME RECEPTIONIST/ADMINISTRATOR
# 60                                       Administrator
# 61          Administration Support - Health (Contract)
# 62                              Accounts Administrator
# 63                       Office / Client Administrator
# 64            ADMINISTRATION SPECIALIST - CONSTRUCTION
# 65                                        Receptionist
# 66                   Office Administrator / Kiripaepae
# 67                                       Administrator
# 68     Information and Sustainable Transport Assistant
# 69                        Team Member Customer Service
# 70           Office Administrator- Flexible Fixed-Term
# 71                                       Administrator
# 72                 Service Delivery Administrator-Wiri
# 73                                    Office Assistant
# 74                              Administration Manager
# 75                 Personal Assistant & Office Manager
# 76                         Customer Care Administrator
# 77                  Office Administrator/ Receptionist
# 78                                Office Administrator
# 79                                Casual Administrator
# 80                           Customer Services Officer
# 81   Remote receptionist / Front of Hours / Account...
# 82        Development Contributions Assessment Officer
# 83                                   Customer Services
# 84      Administrator/Booking  Clerk -  Cardiothoracic
# 85                       Senior Administration Officer
# 86                     Office Administrator (3 Months)
# 87                          Administrator/Receptionist
# 88                                       Administrator
# 89   Office Administrator - Full-time Ellerslie/Mt ...
# 90                      Bilingual Office Administrator
# 91             Administrator, Intelligence & Reporting
# 92                                        Receptionist
# 93                                        Receptionist
# 94                    Client Assistant / Administrator
# 95                                Export Admin Support
# 96                  Contract Administrator / Reception
# 97                                      Administration
# 98                                  Personal Assistant
# 99                              Administration Manager
# 100                            Client Care / Reception
# 101                  Administrator / Marketing Support
# 102                                 Personal Assistant
# 103                          Office Administrator / PA
# 104                            Accounts & Office Admin
# 105                                 Operations Support
# 106                      Office / Client Administrator
# 107                                       Receptionist
# 108                  Building Support Services Officer
# 109                            Logistics Administrator
# 110               Receptionist / Office Administration
# 111           First Impressions Manager/Administration
# 112                  Office Administrator / Kiripaepae
# 113                                  Library Assistant
# 114                              Gateway Administrator
# 115               Customer Services & Admin Specialist
# 116                                       Receptionist
# 117                         Receptionist/Administrator
# 118                                       Receptionist
# 119        Client Liaison and Administration Superstar
# 120                                    Admin Assistant
# 121                    Office Assistant - Christchurch
# 122                          Swim School Administrator
# 123                          Judges Personal Assistant
# 124                                     Office Manager
# 125                                Executive Assistant
# 126                   Admin/Reception - permanent role
# 127         Office / Human Resource (HR) Administrator
# 128                                Service Coordinator
# 129       Receptionist / Administrator - Auckland Wide
# 130             Part time Receptionist in Auckland CBD
# 131         Executive Assistant to the Chief Executive
# 132                               Senior Administrator
# 133                              Office Administrators
# 134                     Student Services Administrator
# 135                                Executive Assistant
# 136                            Inpatient Booking Clerk
# 137                               Office Administrator
# 138                Regional Coordinator - South Island
# 139        Administrator Te Roopu Kaitiaki - Part Time
# 140  Environmental Group Administrator/Liquor Licen...
# 141                   Part Time Administration Officer
# 142   Part-Time Weekend Receptionist - Mount Hot Pools
# 143                                    Board Secretary
# 144                           Receptionist - Part Time
# 145                                     office manager
# 146  Kaiāwhina Rau Tangata - Business Support Repre...
# 147  Receptionist - Raglan Holiday Park Papahua (Ca...
# 148                             Administration Manager
# 149                     Customer Service Administrator
# 150                          Receptionist/Duty Manager
# 151                     Business Support Administrator
# 152                              Estates Administrator
# 153          Executive Assistant/ Support Co-ordinator
# 154                           Customer Service Officer
# 155                     Business Support Administrator
# 156                    Branch and Events Administrator
# 157                               Office Administrator
# 158        Frontline Media/Marketing Office Super Star
# 159            Client Services Administrator (Dunedin)
# 160                                Executive Assistant
# 161                             Accounts Administrator
# 162                                   Parish Secretary
# 163               Client Services Officer - Wellington
# 164                                      Administrator
# 165  Office Administrator - Full-time Ellerslie/Mt ...
# 166                               Regional Coordinator
# 167                                 Personal Assistant
# 168      Weekend Receptionist - Radius Thornleigh Park
# 169                               Office Administrator
# 170                   Client Services Officer - Napier
# 171  Personal Assistant with experience in Landscap...
# 172      Funding Agreements & Reporting  Administrator
# 173      Personal Assistant (Maternity Leave Position)
# 174                             Administration Manager
# 175       Administrator / Customer Service - Part Time
# 176                           Customer Service Officer
# 177                      Accounts and Office Assistant
# 178            Business Support Administrator - Picton
# 179                                Project Coordinator
# 180               Executive Assistant to the ELB & SLT
# 181                                       Receptionist
# 182                  Office Administrator - Waipukurau
# 183                         Receptionist/Administrator
# 184         Team Coordinator Monitoring and Inspection
# 185                  Lodgement Administrator - Dunedin
# 186                                       Receptionist
# 187                     PERSONAL ASSISTANT - PART TIME
# 188                               Weekend Receptionist
# 189    Children's Team Administrator - Oranga Tamariki
# 190                     Business Support Administrator
# 191                   Office Assistance Temporary Role
# 192                     Compliance Support Coordinator
# 193          Administration Officer, Building Services
# 194           Senior Plumbing Administrator /Scheduler
# 195                                 Personal Assistant
# 196                     Administrator - Women's Health
# 197                                 Team Administrator
# 198                               Senior Administrator
# 199                           Customer Service Officer
# 200        Health & Safety Co-ordinator/Office Manager
# 201                        Admin Coordinator (Medical)
# 202      Office Administrator and Accounting Assistant
# 203                       Service Delivery Coordinator
# 204                                          reception
# 205      Service Administrator Fixed Term - Waipukurau
# 206                              Reception - Part Time
# 207                   Electrical Support Administrator
# 208                              PA/Team Administrator
# 209                     Admin and Sales Support Person
# 210                 Curtain Bank Project Administrator
# 211                        Board Secretary (Part Time)
# 212  Centre Administrator / Executive Assistant - H...
# 213  Personal Assistant/Executive Assistant Roles -...
# 214                Administrator Te Whare o Matairangi
# 215                Time Target Rostering Administrator
# 216                 Executive Officer - Te Tai Tokerau
# 217                        ADMINISTRATION/RECEPTIONIST
# 218                                     Office Manager
# 219                   Dispatcher / Project Coordinator
# 220  Administrator, Office of the Deputy Director-G...
# 221                   Executive Assistant - Fixed Term
# 222                                   Business Manager
# 223                           Administration Superstar
# 224                                 Team Administrator
# 225   Operations Coordinator and/or 1:1 Support Worker
# 226                            PA / Team Administrator
# 227                                   Customer Service
# 228                     Team Leader Reception Services
# 229                               Branch Administrator
# 230                    Office Administrator- Henderson
# 231                             Dispatch Administrator
# 232                                Executive Assistant
# 233                     Administrator - New Initiative
# 234         Order processing and Customer Service Role
# 235                           Data Entry Administrator
# 236           Headmaster - St Paul's Collegiate School
# 237   OFFICE ADMINISTRATOR OPPORTUNITY - Dunedin Based
# 238  9 month Fixed Term Contract - Office Administr...
# 239          Brewery Sales and Logistics Administrator
# 240  Administrator - Returns & Repairs team (fixed-...
# 241  Wairau Park - Administration Assistant - Part ...
# 242     Administrator (Academic Registry & Graduation)
# 243                           Commercial Administrator
# 244                            Senior Business Support
# 245                               Office Administrator
# 246                                         Data Entry
# 247                               Office Administrator
# 248  Case Manager - Dynamic Case Manager role in Ta...
# 249                           Membership Administrator
# 250  Finance Administration Team Leader: Citycare W...
# 251               Business Administrator - Chronoptics
# 252                               Helpdesk Coordinator
# 253                                 Client Coordinator
# 254            Part-time Accounts/Office Administrator
# 255                        Manufacturing Administrator
# 256                                   Business Support
# 257  Team Administrator/Coordinator Roles - Express...
# 258  Health Care Home Project Coordinator - 1 year ...
# 259                   Administrator HSNO Reassessments
# 260                                        Team Member
# 261              Regulatory Administration Team Leader
# 262           Office Administrator - Sales Coordinator
# 263                                       Receptionist
# 264                 Contract Administrator / Reception
# 265             Commercial Administrator (28 hrs/week)
# 266                   Team Administrator, (Fixed Term)
# 267                                  ICT Administrator
# 268  Rockstar Executive Assistant - Perfect for Foo...
# 269                                       Receptionist
# 270                         Business Support Associate
# 271                       Client Programme Coordinator
# 272                      Personal Assistant to Partner
# 273                   Retail Assistant & Administrator
# 274                 Administration/Marketing Assistant
# 275                  Personal Assistant to Salesperson
# 276                      Project/Programme Coordinator
# 277                     Customer Service Administrator
# 278                             Administration Manager
# 279                             Transition Coordinator
# 280                             Transition Coordinator
# 281                                 Retail Coordinator
# 282                                    Reception/Admin
# 283          Human Resources and Payroll Administrator
# 284                                 Sales Co-Ordinator
# 285                                  Temps temps Temps
# 286                     Principal's Personal Assistant
# 287                             Administration Manager
# 288                                   Business Support
# 289                 Business Development Administrator
# 290                         Administrator-Maori Health
# 291                           Admin/Accounts Assistant
# 292                          Group Executive Assistant
# 293                     Team Leader Compliance Support
# 294                                 Category Assistant
# 295  Bowel Screening Programme & Endoscopy Service ...
# 296                                     Office Manager
# 297              Operations Coordinator - South Island
# 298                     Senior Court Judges' Associate
# 299                        Sales Support Administrator
# 300                                 Team Administrator
# 301                        Front Desk Role Medical Rec
# 302                      Service Support Administrator
# 303                                         Team Admin
# 304         Business Support Administrator - Part time
# 305        Capital Projects Administrator - Fixed Term
# 306                                        Team Leader
# 307               Referrals and Onboarding Coordinator
# 308                                Executive Assistant
# 309                     Māori Impact Coordinator - ESR
# 310                     Real Estate Personal Assistant
# 311                   Administrator - 6 month contract
# 312                                 Personal Assistant
# 313                               PA Team Adminstrator
# 314        Administrator - Accounts, Sales & Marketing
# 315                                  Medical Secretary
# 316    Reception and Accounts Receivable Administrator
# 317                  Candidate Manager / Administrator
# 318                      Customer Service /Sales/Admin
# 319                                 Team Administrator
# 320                   Administrator - Research Support
# 321                            Contracts Administrator
# 322                          Adviser, Funding Services
# 323  Administrative Support Position Part-time, Tem...
# 324         Executive Assistant to the Chief Executive
# 325                          Adviser, Funding Services
# 326                                Project Coordinator
# 327                                Sales Administrator
# 328                                     Word Processor
# 329                              Duty Collection Agent
# 330       Childrens Team Coordinator - Oranga Tamariki
# 331                               Office Administrator
# 332      Team Administrator (permanent and fixed term)
# 333                      School Administration Manager
# 334  Business Support Administrator - Northland (Wh...
# 335                               Office Administrator
# 336                                      Administrator
# 337                                 Personal Assistant
# 338                        Executive Assistant 2020/69
# 339                                PART-TIME POSITIONS
# 340                       Trade Administrator (Albany)
# 341                                 Personal Assistant
# 342                   Weighbridge & Customer Assistant
# 343                   Administrator - Executive Office
# 344                                 ACES Administrator
# 345                            Office Coordinator / PA
# 346                 Finance and Administration Manager
# 347                              Student Administrator
# 348               Resource and Information Coordinator
# 349                        Part time Admin and glazier
# 350                      Client Services Administrator
# 351                            Assurance Administrator
# 352                   Maintenance Admin Extraordinaire
# 353                       Legal Receptionist/Assistant
# 354            Personal Assistant to Managing Director
# 355                       Customer Solutions Associate
# 356                                 Personal Assistant
# 357                             ACCOUNTS ADMINISTRATOR
# 358                        Accounts / Office Assistant
# 359                      Accounts and Office Assistant
# 360                      Accounts and Office Assistant
# 361                           Customer Care Specialist
# 362                            Technical Administrator
# 363                  PA Admin support to Brand Manager
# 364                               Office Administrator
# 365                              Finance Administrator
# 366            Sales Team Support and Customer Service
# 367                  Candidate Manager / Administrator
# 368                     Commercial Support Coordinator
# 369                                Executive Assistant
# 370                   Coordinator, Government Services
# 371             Executive Assistant to Deputy Director
# 372                     Licensing & Purchasing Officer
# 373                      Service Support Administrator
# 374             Operations Manager - Property Services
# 375                  Property Management Administrator
# 376                        Maintenance Systems Support
# 377                                     Campus Support
# 378                               Case Support Officer
# 379                                Executive Assistant
# 380                                 Site Administrator
# 381  Volunteer Engagement Advisor - 16 hours per we...
# 382  Performance, Reporting and Assurance Coordinat...
# 383                    Customer Service Representative
# 384                     Technology Support Coordinator
# 385                                     Client Liaison
# 386                          Guarantee's Administrator
# 387                         Administration Coordinator
# 388                   Two Fixed Term Kaimahi Positions
# 389                 Asphalt Plant Junior Administrator
# 390                                                 PA
# 391  Data Entry Administrator - Expressions of Inte...
# 392                           FM Contracts Coordinator
# 393                       Office Manager/Administrator
# 394                                      Administrator
# 395                       Regional Contracts Assistant
# 396                                       Receptionist
# 397            Sales Executive - Direct (South Island)
# 398                     Personal Assistant / Secretary
# 399                        Project Support Coordinator
# 400                Data Scanning Operator - Fixed Term
# 401            Administrator - Power Products Division
# 402                                Temp Administrators
# 403                                Banking - Processor
# 404                                Executive Assistant
# 405                                       Receptionist
# 406                  Administration and Client Support
# 407  Customer Solutions Associate - 18 month fixed-...
# 408                                      Administrator
# 409  Executive Assistant, Primary Health Care Syste...
# 410                              Project Administrator
# 411                             Accounts Administrator
# 412  Executive Business Coordinator Cadetship - Gra...
# 413                                           Kaiārahi
# 414                                Project Coordinator
# 415                             Dispatch Administrator
# 416                           Receptionist - Part-time
# 417                               Senior Administrator
# 418                                      Administrator
# 419           Office Manager - Tauranga Container Park
# 420           Office Manager - Tauranga Container Park
# 421                           Administration Assistant
# 422        Financial Administrator - Organisation wide
# 423                 Senior Administration/HSEQ Advisor
# 424       Senior Administration/HSEQ Advisor - Rotorua
# 425                    Junior Administration Assistant
# 426  Centre Manager - Centre for Arts and Social Tr...
# 427                 Coordination & Rostering Team Lead
# 428             Debt Collection Officer - Office Based
# 429  Placement Specialist l Join a growing, Kiwi-ow...
# 430  Management Assistant (Fixed term parental leav...
# 431       Senior Administration/HSEQ Advisor - Rotorua
# 432                          File Prepper - Fixed Term
# 433               Facilities and Security Co-Ordinator
# 434             Administration: Database Administrator
# 435                            Client Business Manager
# 436                            Client Business Manager
# 437                    Receptionist / Office Assistant
# 438                                Committee Secretary
# 439                                     Team Assistant
# 440  Credentialing Specialist l Join a growing, kiw...
# 441  Asset and Maintenance Services Support Co-ordi...
# 442                       Office Manager - IT Industry
# 443                          Key Account Administrator
# 444                                Casual Receptionist
# 445                                Content Coordinator
# 446                                       Receptionist
# 447                              Payroll Administrator
# 448                             Part Time Receptionist
# 449  Support Services Administrator - Finance (PT -...
# 450                                Executive Assistant
# 451                           Receptionist - Part Time
# 452        Administration Roles - Kiwi Lumber Gisborne
# 453                         Administration Coordinator
# 454                        Sales Support Administrator
# 455                      Accounts/Admin Support Person
# 456    Project Support - Administrators & Coordinators
# 457  Logistics and Customer Service - 6 Month Contract
# 458                             PA/Executive Assistant
# 459                   Tax and Compliance Administrator
# 460                        Wairarapa Community Liaison
# 461                                 Personal Assistant
# 462                             Crisisline Coordinator
# 463                                      PA/Legal Exec
# 464                            Reception/Administrator
# 465                            Scheduler Sales Support
# 466                                Executive Assistant
# 467         Executive Assistant to the General Manager
# 468      Collaboration Broker and Project Co-ordinator
# 469                                Executive Assistant
# 470        Personal Assistant / Accounts Administrator
# 471                             Practice Administrator
# 472                     AE Smith - Document Controller
# 473  SALES SUPPORT | Premium Building Products | Ho...
# 474             Jetts NZ - Customer Service Consultant
# 475                                Executive Assistant
# 476  Operations Support Administrator - Kawerau - F...
# 477          Part time Receptionist/Administrator role
# 478                           Part time Office Manager
# 479                               OFFICE ADMINISTRATOR
# 480  Purchasing and Administration Assistant : Full...
# 481                                   School Secretary
# 482                                 Personal Assistant
# 483  Subcontractor Compliance Administrator (Fixed ...
# 484          Part Time Cashier / Office Administration
# 485      Executive Assistant to Global Management Team
# 486                            Contracts Administrator
# 487         Senior Adviser Creative Communities Scheme
# 488  System Support Specialist - Document and Recor...
# 489  Waiuku Mitre 10 - Trade Administration/Sales S...
# 490     Executive Assistant to Chief Financial Officer
# 491                 Sales and Purchase Support Officer
# 492                                          CRM Ninja
# 493                                       Secretary/PA
# 494                               Office Administrator
# 495                             Chiropractic Assistant
# 496         Senior Adviser Creative Communities Scheme
